# %%
print("fcu")
# Out:
# fcu

# %%
'''
作者:劉鎔瑄
日期:0915
說明:這是我第一次練習程式
'''
a=3#a,b是變數
b=5
stringA="我好餓"#stringA是字串變數
print ("Hi")#print是內建函數，把東西印出來
print ("我是")
print (a+b)
print (stringA)
# Out:
# Hi
# 我是
# 8
# 我好餓

# %%
x=7#xy都是變數
y=3
x+y#Result:10
total=x+y
print(total)#Displays:10
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
type(7.3)
# Out:
# float
